# %% [markdown]
# ### How can I replace the 0 values in df_2014 with 1 or the ```df_holiday['Holday']``` value for the index matching the holiday's date?

# %%
import numpy as np
import pandas as pd 
import seaborn
from sklearn import metrics
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn import preprocessing
import matplotlib.pyplot as plt 
import matplotlib.dates as dates
import datetime
from scipy import stats
# %matplotlib inline

# %% [markdown]
# **Grab data from master NYC file, sort and group to show complaint amount by type for each day**

# %%
cols = ['Created_Date', 'Complaint_Type']
df = pd.read_csv('NYC.csv', parse_dates=['Created_Date'], usecols=cols, index_col='Created_Date')
df = pd.get_dummies(df.Complaint_Type)
df = df.reset_index()
df = df.groupby(df['Created_Date']).sum()
df.reset_index().head()
df = df.sort_index()

# %% [markdown]
# **Read in weather data for the years being analyzed and index by date**

# %%
keepers = ['EST', 'Max TemperatureF', 'Events']
df_weather_2014 = pd.read_csv('clean_2014_weather.csv', usecols=keepers, parse_dates='EST')
df_weather_2015 = pd.read_csv('clean_2015_weather.csv', usecols=keepers, parse_dates='EST')
df_weather_2016 = pd.read_csv('nyc_2016_weather.csv', parse_dates='Created_Date')
df_weather_2014 = df_weather_2014.set_index('EST')
df_weather_2015 = df_weather_2015.set_index('EST')

# %%
df_weather_2016['Created_Date'] = pd.to_datetime(df_weather_2016['Created_Date'])
df_weather_2016 = df_weather_2016.set_index('Created_Date')

# %%
df_weather_2016.head()
# Out:
#              Max TempF
# Created_Date
# 2016-01-01         42°
# 2016-01-02         40°
# 2016-01-03         45°
# 2016-01-04         36°
# 2016-01-05         29°

# %%
df_weather_2015.head()
# Out:
#           Max TemperatureF    Events
# EST
# 2015-1-1                40     Sunny
# 2015-1-2                45     Sunny
# 2015-1-3                47      Rain
# 2015-1-4                55  Fog-Rain
# 2015-1-5                51     Sunny

# %% [markdown]
# **Join the weather event to the year's dataframe, initialize 'Holiday' column with 0 vals**

# %%
year_array = np.arange('2016-01', '2017-01', dtype='datetime64[D]')

# %%
df_2016 = pd.DataFrame(arr)

# %%
df_2016['Created_Date'] = df_2016

# %%
df_2014 = df[:365].join(df_weather_2014)
df_2015 = df[365:].join(df_weather_2015)
df_2016 = df_2016.join(df_weather_2016)
df_2014['Holiday'] = 0
df_2015['Holiday'] = 0
df_2016['Holiday'] = 0

# %%
df_2014.head()
# Out:
#               Building Conditions  General Request or Complaint  \
# Created_Date
# 2014-01-01                   1512                           388
# 2014-01-02                   3236                           921
# 2014-01-03                   3712                           624
# 2014-01-04                   4347                           489
# 2014-01-05                   2529                           500
#
#               Living Conditions  Parking Enforcement  Signal/Sign Repair  \
# Created_Date
# 2014-01-01                  155                  336                 139
# 2014-01-02                  263                  360                 315
# 2014-01-03                  235                  306                 240
# 2014-01-04                  154                  375                 130
# 2014-01-05                  169                  361                 206
#
#               Street/Sidewalk Maintenance  Max TemperatureF    Events  Holiday
# Created_Date
# 2014-01-01                            303                34     Sunny        0
# 2014-01-02                            320                33      Snow        0
# 2014-01-03                            516                19  Fog-Snow        0
# 2014-01-04                           1188                31     Sunny        0
# 2014-01-05                           1022                49  Fog-Rain        0

# %% [markdown]
# **Rename columns to better fit my screen**

# %%
df_2014.columns = ['Building Conditions', 'General Request', 'Living Conditions', 'Parking Enforcement', 'Signal/Sign Repair', 'Street/Sidewalk Repair', 'Max TempF', 'Weather', 'Holiday']
df_2015.columns = ['Building Conditions', 'General Request', 'Living Conditions', 'Parking Enforcement', 'Signal/Sign Repair', 'Street/Sidewalk Repair', 'Max TempF', 'Weather', 'Holiday']

# %% [markdown]
# **Read in holiday csv, contains holidays and dates for each year**

# %%
df_holidays = pd.read_csv('../../../holidays.csv', parse_dates=['2014_date', '2015_date'])

# %%
df_holidays2 = df_holidays.set_index('2014_date')
df_holidays3 = df_holidays.set_index('2015_date')

# %%
df_2014.join(df_holidays2, lsuffix='_')
df_2015.join(df_holidays3, lsuffix='_')
# Out:
#               Building Conditions  General Request  Living Conditions  \
# Created_Date
# 2015-01-01                   1607              369                273
# 2015-01-02                   1935              604                581
# 2015-01-03                   1527              465                369
# 2015-01-04                   1230              395                403
# 2015-01-05                   2797              748                705
# 2015-01-06                   3702              729                552
# 2015-01-07                   5375              773                637
# 2015-01-08                   7137              723                671
# 2015-01-09                   4384              594                564
# 2015-01-10                   3249              503                357
# 2015-01-11                   2508              457                343
# 2015-01-12                   2507              652                675
# 2015-01-13                   2856              675                665
# 2015-01-14                   2790              570                511
# 2015-01-15                   1932              564                535
# 2015-01-16                   1973              644                611
# 2015-01-17                   2242              451                406
# 2015-01-18                   1480              416                604
# 2015-01-19                   1704              512                563
# 2015-01-20                   2236              732                710
# 2015-01-21                   2533              744                703
# 2015-01-22                   2315              680                682
# 2015-01-23                   2166              757                598
# 2015-01-24                   1613              498                377
# 2015-01-25                   1281              444                371
# 2015-01-26                   3078              626                495
# 2015-01-27                   2475              290                402
# 2015-01-28                   2725              874                496
# 2015-01-29                   2390              908                519
# 2015-01-30                   2108              856                465
# ...                           ...              ...                ...
# 2015-12-02                   2226              839                757
# 2015-12-03                   2261              845                681
# 2015-12-04                   2341              836                672
# 2015-12-05                   1512              738                438
# 2015-12-06                   1310              585                387
# 2015-12-07                   2221              805                776
# 2015-12-08                   2297              800                735
# 2015-12-09                   2072              824                730
# 2015-12-10                   1501              783                674
# 2015-12-11                   1410              723                650
# 2015-12-12                    833              838                411
# 2015-12-13                    748              664                406
# 2015-12-14                   1684              800                807
# 2015-12-15                   1807              781                789
# 2015-12-16                   2024              737                631
# 2015-12-17                   1621              724                741
# 2015-12-18                   1905              746                663
# 2015-12-19                   2687              604                455
# 2015-12-20                   1913              527                363
# 2015-12-21                   2201              673                671
# 2015-12-22                   1403              693                650
# 2015-12-23                   1433              641                812
# 2015-12-24                    936              437                469
# 2015-12-25                    412              270                237
# 2015-12-26                    828              401                313
# 2015-12-27                    952              434                358
# 2015-12-28                   2381              710                731
# 2015-12-29                   2568              708                755
# 2015-12-30                   2087              757                759
# 2015-12-31                      0                1                 60
#
#               Parking Enforcement  Signal/Sign Repair  Street/Sidewalk Repair  \
# Created_Date
# 2015-01-01                    438                 112                     264
# 2015-01-02                    588                 282                     499
# 2015-01-03                    511                 156                     322
# 2015-01-04                    486                 165                     357
# 2015-01-05                    625                 537                     734
# 2015-01-06                    570                 621                     662
# 2015-01-07                    505                 315                     709
# 2015-01-08                    558                 682                     770
# 2015-01-09                    575                 613                     452
# 2015-01-10                    514                 142                     386
# 2015-01-11                    485                 127                     507
# 2015-01-12                    591                 631                     650
# 2015-01-13                    603                 516                     766
# 2015-01-14                    432                 417                     720
# 2015-01-15                    489                 442                     781
# 2015-01-16                    504                 554                     695
# 2015-01-17                    473                 149                     437
# 2015-01-18                    345                 248                     518
# 2015-01-19                    529                 255                     577
# 2015-01-20                    601                 485                     752
# 2015-01-21                    608                 515                     856
# 2015-01-22                    616                 531                     759
# 2015-01-23                    589                 547                     797
# 2015-01-24                    560                 238                     467
# 2015-01-25                    479                 125                     504
# 2015-01-26                    420                 412                     351
# 2015-01-27                    280                 274                     672
# 2015-01-28                    556                 579                    1590
# 2015-01-29                    620                 592                    1141
# 2015-01-30                    596                 569                     662
# ...                           ...                 ...                     ...
# 2015-12-02                    824                 432                     509
# 2015-12-03                    855                 614                     860
# 2015-12-04                    860                 415                     657
# 2015-12-05                    749                 163                     425
# 2015-12-06                    743                 109                     483
# 2015-12-07                    899                 558                     958
# 2015-12-08                    778                 516                     684
# 2015-12-09                    796                 559                     669
# 2015-12-10                    878                 647                     697
# 2015-12-11                    875                 462                     703
# 2015-12-12                    822                 184                     630
# 2015-12-13                    654                 103                     462
# 2015-12-14                    919                 558                     691
# 2015-12-15                    930                 503                     738
# 2015-12-16                    835                 538                     625
# 2015-12-17                    849                 600                     532
# 2015-12-18                    755                 515                     489
# 2015-12-19                    686                 123                     329
# 2015-12-20                    678                 129                     354
# 2015-12-21                    880                 725                     542
# 2015-12-22                    847                 461                     527
# 2015-12-23                    715                 476                     469
# 2015-12-24                    802                 384                     499
# 2015-12-25                    469                  71                     333
# 2015-12-26                    591                  71                     304
# 2015-12-27                    606                 118                     346
# 2015-12-28                    788                 423                     608
# 2015-12-29                    776                 534                     490
# 2015-12-30                    744                 483                     499
# 2015-12-31                      0                   0                       0
#
#               Max TempF        Weather  Holiday_                     Holiday  \
# Created_Date
# 2015-01-01           40          Sunny         0              New Year's Day
# 2015-01-02           45          Sunny         0                         NaN
# 2015-01-03           47           Rain         0                         NaN
# 2015-01-04           55       Fog-Rain         0                         NaN
# 2015-01-05           51          Sunny         0                         NaN
# 2015-01-06           23           Snow         0                         NaN
# 2015-01-07           25          Sunny         0                         NaN
# 2015-01-08           22          Sunny         0                         NaN
# 2015-01-09           34           Snow         0                         NaN
# 2015-01-10           24          Sunny         0                         NaN
# 2015-01-11           38          Sunny         0                         NaN
# 2015-01-12           40           Rain         0                         NaN
# 2015-01-13           37          Sunny         0                         NaN
# 2015-01-14           33          Sunny         0                         NaN
# 2015-01-15           35          Sunny         0                         NaN
# 2015-01-16           45          Sunny         0                         NaN
# 2015-01-17           32          Sunny         0                         NaN
# 2015-01-18           47       Fog-Rain         0                         NaN
# 2015-01-19           45          Sunny         0  Martin Luther King Jr. Day
# 2015-01-20           41          Sunny         0                         NaN
# 2015-01-21           38           Snow         0                         NaN
# 2015-01-22           41          Sunny         0                         NaN
# 2015-01-23           39           Snow         0                         NaN
# 2015-01-24           40  Fog-Rain-Snow         0                         NaN
# 2015-01-25           45          Sunny         0                         NaN
# 2015-01-26           32           Snow         0                         NaN
# 2015-01-27           27           Snow         0                         NaN
# 2015-01-28           33          Sunny         0                         NaN
# 2015-01-29           37           Snow         0                         NaN
# 2015-01-30           38           Snow         0                         NaN
# ...                 ...            ...       ...                         ...
# 2015-12-02           57       Fog-Rain         0                         NaN
# 2015-12-03           56          Sunny         0                         NaN
# 2015-12-04           53          Sunny         0                         NaN
# 2015-12-05           53          Sunny         0                         NaN
# 2015-12-06           51          Sunny         0                         NaN
# 2015-12-07           55          Sunny         0                         NaN
# 2015-12-08           51          Sunny         0                         NaN
# 2015-12-09           55          Sunny         0                         NaN
# 2015-12-10           59          Sunny         0                         NaN
# 2015-12-11           58            Fog         0                         NaN
# 2015-12-12           64          Sunny         0                         NaN
# 2015-12-13           70          Sunny         0                         NaN
# 2015-12-14           61       Fog-Rain         0                         NaN
# 2015-12-15           64           Rain         0                         NaN
# 2015-12-16           53           Rain         0                         NaN
# 2015-12-17           59           Rain         0                         NaN
# 2015-12-18           58           Rain         0                         NaN
# 2015-12-19           41          Sunny         0                         NaN
# 2015-12-20           44          Sunny         0                         NaN
# 2015-12-21           55          Sunny         0                         NaN
# 2015-12-22           60           Rain         0                         NaN
# 2015-12-23           63       Fog-Rain         0                         NaN
# 2015-12-24           69       Fog-Rain         0                         NaN
# 2015-12-25           64       Fog-Rain         0               Christmas Day
# 2015-12-26           60           Rain         0                         NaN
# 2015-12-27           63       Fog-Rain         0                         NaN
# 2015-12-28           48      Rain-Snow         0                         NaN
# 2015-12-29           49      Rain-Snow         0                         NaN
# 2015-12-30           51           Rain         0                         NaN
# 2015-12-31           52           Rain         0                         NaN
#
#               2014_date
# Created_Date
# 2015-01-01   2014-01-01
# 2015-01-02          NaT
# 2015-01-03          NaT
# 2015-01-04          NaT
# 2015-01-05          NaT
# 2015-01-06          NaT
# 2015-01-07          NaT
# 2015-01-08          NaT
# 2015-01-09          NaT
# 2015-01-10          NaT
# 2015-01-11          NaT
# 2015-01-12          NaT
# 2015-01-13          NaT
# 2015-01-14          NaT
# 2015-01-15          NaT
# 2015-01-16          NaT
# 2015-01-17          NaT
# 2015-01-18          NaT
# 2015-01-19   2014-01-20
# 2015-01-20          NaT
# 2015-01-21          NaT
# 2015-01-22          NaT
# 2015-01-23          NaT
# 2015-01-24          NaT
# 2015-01-25          NaT
# 2015-01-26          NaT
# 2015-01-27          NaT
# 2015-01-28          NaT
# 2015-01-29          NaT
# 2015-01-30          NaT
# ...                 ...
# 2015-12-02          NaT
# 2015-12-03          NaT
# 2015-12-04          NaT
# 2015-12-05          NaT
# 2015-12-06          NaT
# 2015-12-07          NaT
# 2015-12-08          NaT
# 2015-12-09          NaT
# 2015-12-10          NaT
# 2015-12-11          NaT
# 2015-12-12          NaT
# 2015-12-13          NaT
# 2015-12-14          NaT
# 2015-12-15          NaT
# 2015-12-16          NaT
# 2015-12-17          NaT
# 2015-12-18          NaT
# 2015-12-19          NaT
# 2015-12-20          NaT
# 2015-12-21          NaT
# 2015-12-22          NaT
# 2015-12-23          NaT
# 2015-12-24          NaT
# 2015-12-25   2014-12-25
# 2015-12-26          NaT
# 2015-12-27          NaT
# 2015-12-28          NaT
# 2015-12-29          NaT
# 2015-12-30          NaT
# 2015-12-31          NaT
#
# [365 rows x 11 columns]

# %%
df_2014_final = df_2014.join(df_holidays2, lsuffix='_')
df_2015_final = df_2015.join(df_holidays3, lsuffix='_')

# %%
df_2014_final = df_2014_final.drop('Holiday_', axis=1).fillna(0)
df_2014_final = df_2014_final.drop('2015_date', axis=1).fillna(0)
df_2015_final = df_2015_final.drop('Holiday_', axis=1).fillna(0)
df_2015_final = df_2015_final.drop('2014_date', axis=1).fillna(0)

# %%
df_2014_final['Holiday'] = (df_2014_final['Holiday'] != 0).astype(int)
df_2015_final['Holiday'] = (df_2015_final['Holiday'] != 0).astype(int)

# %%
encode = preprocessing.LabelEncoder()

# %%
encode.fit(df_2014_final['Max TempF'])
# Out:
# LabelEncoder()

# %%
df_2014_final['Max TempF'] = encode.transform(df_2014_final['Max TempF'])

# %%
encode.fit(df_2015_final['Max TempF'])
# Out:
# LabelEncoder()

# %%
df_2015_final['Max TempF'] = encode.transform(df_2015_final['Max TempF'])

# %%
X_2014 = df_2014_final.reset_index(drop=True)
y_2014 = df_2014_final['Max TempF']
X_2015 = df_2015_final.reset_index(drop=True)
y_2015 = df_2015_final['Max TempF']

# %%
X_train = X_2014
X_test = X_2015

# %%
y_train = y_2014.values
y_test = y_2015.values

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print('Coefficients: \n', lr.coef_)
print("Residual sum of squares: %.2f"
      % np.mean((lr.predict(X_test) - y_test) ** 2))
print('Variance score: %.2f' % lr.score(X_test, y_test))
# Out:
# ('Coefficients: \n', array([ -5.60762281e-19,   1.12189514e-18,  -2.08581863e-19,
#         -6.08180244e-18,   2.23754341e-18,  -4.31404468e-19,
#         -2.45343093e-17,   1.00000000e+00,  -8.56953397e-16]))
# Residual sum of squares: 0.00
# Variance score: 1.00

# %%
print len(X_test)
print len(y_test)
# Out:
# 365
# 365

# %%
plt.plot(X_test, lr.predict(X_test), color='blue')
plt.xticks(())
plt.yticks(())

plt.show()
